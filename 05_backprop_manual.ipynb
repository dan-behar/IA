# %% [markdown]
# # Gradient Descent y Backpropagation

# %% [markdown]
# Problema 1. Revisión de gráfo computacional
#
# Supongamos que tenemos una función simple $f(x, y, z)=(x + y) z$
#
# Podemos dividir esto en las ecuaciones $q=x+y$ y $f(x,y,z)=qz$. Usando esta notación simplificada, también podemos representar esta ecuación como un gráfo de cálculo:
#
# ![Screen Shot 2022-09-05 at 12.29.09.png](data:image/png;base64,...)
#
# Ahora supongamos que estamos evaluando esta función en $x=-2$, $y=5$ y $z=-4$. Además, asumamos que el valor del gradiente _upstream_  (gradiente del loss con respecto a nuestra función, ∂L/∂f) sea igual a ​1​. Estos estan rellenados en el grafo computacional.
#
# Resuelvan para los siguientes valores, tanto simbólicamente (sin meter valores específicos de x/y/z) como evaluados en ​$x=-2$,​ ​$y=5$,​ $​z=-4$​ y $​∂L/ ∂f = 1$​:

# %% [markdown]
# Simbolicamente:
#
# 1.∂f/∂q=
#
# 2.∂q/∂x=
#
# 3.∂q/∂y=
#
# 4.∂f/∂z=
#
# 5.∂f/∂x=
#
# 6.∂f/∂y=
#
# Evaluados:
#
# ∂f/∂q=
#
# ∂q/∂x=
#
# ∂q/∂y=
#
# ∂f/∂z=
#
# ∂f/∂x=
#
# ∂f/∂y=

# %% [markdown]
# Ahora hagamos backprop a través de una sola neurona de una red neuronal con una activación sigmoid. En concreto, definimos la preactivación $z= w_ox_o+w_1x_1+w_2$ y definimos el valor de activación $α=σ(z) = 1 / (1 + e−z )$ . El grafo de calculo resultante:
#
# ![Screen Shot 2022-09-05 at 12.46.03.png](data:image/png;base64,...)
#
#
# En el grafo esta rellenadon las ​activaciones del forward pass,​ arriba de las líneas, así como el gradiente _upstream_ (gradiente del loss con respecto a nuestra neurona, ∂L/∂α). Usen esta información para calcular el resto de los gradientes (marcados con ​signos de interrogación​) a lo largo del gráfo.
#
# Finalmente, encuentren los gradientes simbólicos con respecto a los parámetros de entrada, $x_o$, $x_1$, $w_0$, $w1$, $w2$:

# %% [markdown]
# 1. ∂α/∂x0 =
# 2. ∂α/∂w0 =
# 3. ∂α/∂x1 =
# 4. ∂α/∂w1 =
# 5. ∂α/∂w2 =
